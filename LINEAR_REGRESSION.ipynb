# %% [markdown]
# <a href="https://colab.research.google.com/github/VAISHNAVISUROJU/H1vaishnavi/blob/main/LINEAR_REGRESSION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x = np.array([[1], [2], [3], [4], [5]])
y = np.array([1, 2, 2.5, 4, 5])

# %%
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x)

# %%
plt.scatter(x, y, color='black')
plt.plot(x, y_pred, color='blue')
plt.title("linear regression")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
print("inter (βθ):", model.intercept_)
print("coefficient (β1):", model.coef_)
# Out:
# inter (βθ): -0.10000000000000009
# coefficient (β1): [1.]

# %%
X = np.random.rand(100, 1) * 100
Y = 2 * X + np.random.randn(100, 1) * 10

# %%
plt.scatter(X, Y, color='blue')
plt.title("Generated Dataset of 100 Numbers")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X)

# %%
plt.scatter(X, Y, color='blue')  # Actual data points
plt.plot(X, Y_pred, color='red')  # Regression line
plt.title("Linear Regression")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
print("Intercept (β0):", model.intercept_)
print("Coefficient (β1):", model.coef_)
# Out:
# Intercept (β0): [2.74247407]
# Coefficient (β1): [[1.95345245]]

# %%
import pandas as pd

# %%
df = pd.read_csv("diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0              6      148             72  ...                     0.627   50        1
# 1              1       85             66  ...                     0.351   31        0
# 2              8      183             64  ...                     0.672   32        1
# 3              1       89             66  ...                     0.167   21        0
# 4              0      137             40  ...                     2.288   33        1
# ..           ...      ...            ...  ...                       ...  ...      ...
# 763           10      101             76  ...                     0.171   63        0
# 764            2      122             70  ...                     0.340   27        0
# 765            5      121             72  ...                     0.245   30        0
# 766            1      126             60  ...                     0.349   47        1
# ...

# %%
a = df[['Glucose']]
b = df[['BloodPressure']]

# %%
model = LinearRegression()
model.fit(a, b)
# Out:
# LinearRegression()

# %%
b_pred = model.predict(a)

# %%
plt.scatter(a, b, color='blue')  # Actual data points
plt.plot(a, b_pred, color='red')  # Regression line
plt.title("Linear Regression")
plt.xlabel("a")
plt.ylabel("b")
plt.show()
